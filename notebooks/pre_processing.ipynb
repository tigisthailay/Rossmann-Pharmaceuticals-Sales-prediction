# %% [markdown]
# ### Exploring Rossmann Pharmaceuticals

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sys, os

# %% [markdown]
# Import modules from Scripts

# %%
sys.path.append(os.path.abspath(os.path.join('../scripts')))
from preprocessing import Preprocess
from plotting import Plotting
from file import Myfile

# %% [markdown]
# Initialize class

# %%
file = Myfile()
preprocess = Preprocess()
plot = Plotting()

# %%
sub_df = file.read_csv('../data/sample_submission.csv')
test_df = file.read_csv('../data/test.csv')
store_df = file.read_csv('../data/store.csv')
train_df = file.read_csv('../data/train.csv')
# Out:
# --> file read as csv
# --> file read as csv
# --> file read as csv
# C:\Users\user\Desktop\10Academy\Week-3\Rossmann-Pharmaceuticals-Sales-prediction\scripts\file.py:11: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(path)
# --> file read as csv

# %% [markdown]
# Data overview of each dataset

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41088 entries, 0 to 41087
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             41088 non-null  int64
#  1   Store          41088 non-null  int64
#  2   DayOfWeek      41088 non-null  int64
#  3   Date           41088 non-null  object
#  4   Open           41077 non-null  float64
#  5   Promo          41088 non-null  int64
#  6   StateHoliday   41088 non-null  object
#  7   SchoolHoliday  41088 non-null  int64
# dtypes: float64(1), int64(5), object(2)
# memory usage: 2.5+ MB

# %%
test_df.head()
# Out:
#    Id  Store  DayOfWeek        Date  Open  Promo StateHoliday  SchoolHoliday
# 0   1      1          4  2015-09-17   1.0      1            0              0
# 1   2      3          4  2015-09-17   1.0      1            0              0
# 2   3      7          4  2015-09-17   1.0      1            0              0
# 3   4      8          4  2015-09-17   1.0      1            0              0
# 4   5      9          4  2015-09-17   1.0      1            0              0

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1017209 entries, 0 to 1017208
# Data columns (total 9 columns):
#  #   Column         Non-Null Count    Dtype
# ---  ------         --------------    -----
#  0   Store          1017209 non-null  int64
#  1   DayOfWeek      1017209 non-null  int64
#  2   Date           1017209 non-null  object
#  3   Sales          1017209 non-null  int64
#  4   Customers      1017209 non-null  int64
#  5   Open           1017209 non-null  int64
#  6   Promo          1017209 non-null  int64
#  7   StateHoliday   1017209 non-null  object
#  8   SchoolHoliday  1017209 non-null  int64
# dtypes: int64(7), object(2)
# memory usage: 69.8+ MB

# %%
train_df.head()
# Out:
#    Store  DayOfWeek        Date  Sales  Customers  Open  Promo StateHoliday  \
# 0      1          5  2015-07-31   5263        555     1      1            0
# 1      2          5  2015-07-31   6064        625     1      1            0
# 2      3          5  2015-07-31   8314        821     1      1            0
# 3      4          5  2015-07-31  13995       1498     1      1            0
# 4      5          5  2015-07-31   4822        559     1      1            0
#
#    SchoolHoliday
# 0              1
# 1              1
# 2              1
# 3              1
# 4              1

# %%
store_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1115 entries, 0 to 1114
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Store                      1115 non-null   int64
#  1   StoreType                  1115 non-null   object
#  2   Assortment                 1115 non-null   object
#  3   CompetitionDistance        1112 non-null   float64
#  4   CompetitionOpenSinceMonth  761 non-null    float64
#  5   CompetitionOpenSinceYear   761 non-null    float64
#  6   Promo2                     1115 non-null   int64
#  7   Promo2SinceWeek            571 non-null    float64
#  8   Promo2SinceYear            571 non-null    float64
#  9   PromoInterval              571 non-null    object
# dtypes: float64(5), int64(2), object(3)
# memory usage: 87.2+ KB

# %%
store_df.head()
# Out:
#    Store StoreType Assortment  CompetitionDistance  CompetitionOpenSinceMonth  \
# 0      1         c          a               1270.0                        9.0
# 1      2         a          a                570.0                       11.0
# 2      3         a          a              14130.0                       12.0
# 3      4         c          c                620.0                        9.0
# 4      5         a          a              29910.0                        4.0
#
#    CompetitionOpenSinceYear  Promo2  Promo2SinceWeek  Promo2SinceYear  \
# 0                    2008.0       0              NaN              NaN
# 1                    2007.0       1             13.0           2010.0
# 2                    2006.0       1             14.0           2011.0
# 3                    2009.0       0              NaN              NaN
# 4                    2015.0       0              NaN              NaN
#
#      PromoInterval
# 0              NaN
# 1  Jan,Apr,Jul,Oct
# ...

# %% [markdown]
# Check for shape of our datasets

# %%
test_df.shape
# Out:
# (41088, 8)

# %%
train_df.shape
# Out:
# (1017209, 9)

# %%
store_df.shape
# Out:
# (1115, 10)

# %% [markdown]
# let convert the date column to datetime datatype on both train and test dataset

# %%
test_df = preprocess.convert_to_datetime(test_df, 'Date')
train_df = preprocess.convert_to_datetime(train_df, 'Date')

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41088 entries, 0 to 41087
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             41088 non-null  int64
#  1   Store          41088 non-null  int64
#  2   DayOfWeek      41088 non-null  int64
#  3   Date           41088 non-null  datetime64[ns]
#  4   Open           41077 non-null  float64
#  5   Promo          41088 non-null  int64
#  6   StateHoliday   41088 non-null  object
#  7   SchoolHoliday  41088 non-null  int64
# dtypes: datetime64[ns](1), float64(1), int64(5), object(1)
# memory usage: 2.5+ MB

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1017209 entries, 0 to 1017208
# Data columns (total 9 columns):
#  #   Column         Non-Null Count    Dtype
# ---  ------         --------------    -----
#  0   Store          1017209 non-null  int64
#  1   DayOfWeek      1017209 non-null  int64
#  2   Date           1017209 non-null  datetime64[ns]
#  3   Sales          1017209 non-null  int64
#  4   Customers      1017209 non-null  int64
#  5   Open           1017209 non-null  int64
#  6   Promo          1017209 non-null  int64
#  7   StateHoliday   1017209 non-null  object
#  8   SchoolHoliday  1017209 non-null  int64
# dtypes: datetime64[ns](1), int64(7), object(1)
# memory usage: 69.8+ MB

# %% [markdown]
# #### Now Merge the dataframes

# %%
train_jdf = preprocess.join_dataframes(train_df, store_df, 'Store', 'left')
test_jdf = preprocess.join_dataframes(test_df, store_df, 'Store', 'left')

# %% [markdown]
# Extract relevant fields from Date column

# %%
train_jdf = preprocess.extract_fields_date(train_jdf, 'Date')
test_jdf = preprocess.extract_fields_date(test_jdf, 'Date')
# Out:
# C:\Users\user\Desktop\10Academy\Week-3\Rossmann-Pharmaceuticals-Sales-prediction\scripts\preprocessing.py:168: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated. Please use Series.dt.isocalendar().week instead.
#   df['weekofyear'] = df[date_column].dt.weekofyear
# C:\Users\user\Desktop\10Academy\Week-3\Rossmann-Pharmaceuticals-Sales-prediction\scripts\preprocessing.py:168: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated. Please use Series.dt.isocalendar().week instead.
#   df['weekofyear'] = df[date_column].dt.weekofyear

# %%
train_jdf.head()
# Out:
#    Store  DayOfWeek       Date  Sales  Customers  Open  Promo StateHoliday  \
# 0      1          4 2015-07-31   5263        555     1      1            0
# 1      1          3 2015-07-30   5020        546     1      1            0
# 2      1          2 2015-07-29   4782        523     1      1            0
# 3      1          1 2015-07-28   5011        560     1      1            0
# 4      1          0 2015-07-27   6102        612     1      1            0
#
#    SchoolHoliday StoreType  ... Promo2  Promo2SinceWeek  Promo2SinceYear  \
# 0              1         c  ...      0              NaN              NaN
# 1              1         c  ...      0              NaN              NaN
# 2              1         c  ...      0              NaN              NaN
# 3              1         c  ...      0              NaN              NaN
# 4              1         c  ...      0              NaN              NaN
#
#    PromoInterval  Year  Month  Day weekday  weekofyear  weekend
# ...

# %%
test_jdf.head()
# Out:
#      Id  Store  DayOfWeek       Date  Open  Promo StateHoliday  SchoolHoliday  \
# 0     1      1          3 2015-09-17   1.0      1            0              0
# 1   857      1          2 2015-09-16   1.0      1            0              0
# 2  1713      1          1 2015-09-15   1.0      1            0              0
# 3  2569      1          0 2015-09-14   1.0      1            0              0
# 4  3425      1          6 2015-09-13   0.0      0            0              0
#
#   StoreType Assortment  ...  Promo2  Promo2SinceWeek  Promo2SinceYear  \
# 0         c          a  ...       0              NaN              NaN
# 1         c          a  ...       0              NaN              NaN
# 2         c          a  ...       0              NaN              NaN
# 3         c          a  ...       0              NaN              NaN
# 4         c          a  ...       0              NaN              NaN
#
#    PromoInterval  Year  Month Day  weekday  weekofyear  weekend
# ...

# %% [markdown]
# Set the Date as an index

# %%
train_jdf.set_index('Date', inplace=True)
test_jdf.set_index('Date', inplace=True)

# %% [markdown]
# save the merged dataset

# %%
train_jdf.to_csv('../data/train_joined.csv', index=True)
test_jdf.to_csv('../data/test_joined.csv', index=True)

# %% [markdown]
# LOad the saved merged data set

# %%
train_df = file.read_csv('../data/train_joined.csv')
test_df = file.read_csv('../data/test_joined.csv')
# Out:
# --> file read as csv
# --> file read as csv

# %% [markdown]
# #### Null Percentages

# %%
#nullpercentage for test dataset
print(f"Test Null Percentage : {preprocess.get_missing_data_percentage(test_df)} %")
# Out:
# Test Null Percentage :                            Total     %
# PromoInterval              17232  41.9
# Promo2SinceYear            17232  41.9
# Promo2SinceWeek            17232  41.9
# CompetitionOpenSinceMonth  15216  37.0
# CompetitionOpenSinceYear   15216  37.0
# CompetitionDistance           96   0.2
# Open                          11   0.0
# Promo2                         0   0.0
# weekofyear                     0   0.0
# weekday                        0   0.0
# Day                            0   0.0
# Month                          0   0.0
# Year                           0   0.0
# Date                           0   0.0
# Id                             0   0.0
# Assortment                     0   0.0
# StoreType                      0   0.0
# SchoolHoliday                  0   0.0
# StateHoliday                   0   0.0
# Promo                          0   0.0
# DayOfWeek                      0   0.0
# Store                          0   0.0
# ...

# %%
#train null percentage
print(f"Train Null Percentage : {preprocess.get_missing_data_percentage(train_df)} %")
# Out:
# Train Null Percentage :                             Total     %
# PromoInterval              508031  49.9
# Promo2SinceYear            508031  49.9
# Promo2SinceWeek            508031  49.9
# CompetitionOpenSinceMonth  323348  31.8
# CompetitionOpenSinceYear   323348  31.8
# CompetitionDistance          2642   0.3
# weekofyear                      0   0.0
# weekday                         0   0.0
# Day                             0   0.0
# Month                           0   0.0
# Year                            0   0.0
# Promo2                          0   0.0
# Date                            0   0.0
# Store                           0   0.0
# Assortment                      0   0.0
# StoreType                       0   0.0
# SchoolHoliday                   0   0.0
# StateHoliday                    0   0.0
# Promo                           0   0.0
# Open                            0   0.0
# Customers                       0   0.0
# Sales                           0   0.0
# ...

# %% [markdown]
# * PromoInterval(Object), Promo2SinceYear(float64), Promo2SinceWeek(float64), CompetitionOpenSinceMonth(float64),
#   CompetitionOpenSinceYear(float64), CompetitionDistance(float64) are missing values.
#
# * Open(float64) is missing in the test data in addition to the other missing values.

# %%
#test missed columns
missing_df = test_df[['PromoInterval', 'Promo2SinceYear', 'Promo2SinceWeek', 'CompetitionOpenSinceMonth', 'CompetitionOpenSinceYear', 'CompetitionDistance', 'Open']]
missing_df.head(10)
# Out:
#   PromoInterval  Promo2SinceYear  Promo2SinceWeek  CompetitionOpenSinceMonth  \
# 0           NaN              NaN              NaN                        9.0
# 1           NaN              NaN              NaN                        9.0
# 2           NaN              NaN              NaN                        9.0
# 3           NaN              NaN              NaN                        9.0
# 4           NaN              NaN              NaN                        9.0
# 5           NaN              NaN              NaN                        9.0
# 6           NaN              NaN              NaN                        9.0
# 7           NaN              NaN              NaN                        9.0
# 8           NaN              NaN              NaN                        9.0
# 9           NaN              NaN              NaN                        9.0
#
#    CompetitionOpenSinceYear  CompetitionDistance  Open
# 0                    2008.0               1270.0   1.0
# ...

# %% [markdown]
# #### Handling Missing Value

# %% [markdown]
# fill the numeric columns  'Promo2SinceYear', 'Promo2SinceWeek', 'CompetitionOpenSinceMonth', 'CompetitionOpenSinceYear', 'CompetitionDistance' with mean values

# %%
#handling numeric column with median
miss = ['Promo2SinceYear', 'Promo2SinceWeek', 'CompetitionOpenSinceMonth', 'CompetitionOpenSinceYear', 'CompetitionDistance']
train_df = preprocess.fill_missing_median(train_df, miss)
test_df = preprocess.fill_missing_median(test_df, miss)

# %% [markdown]
# Fill the Object column with mode

# %%
#handling object column with mode
train_df = preprocess.fill_missing_mode(train_df, ['PromoInterval'])
test_df = preprocess.fill_missing_mode(test_df, ['PromoInterval'])

# %% [markdown]
# Fill Open with zero

# %%
test_df = preprocess.fill_missing_with_zero(test_df, ['Open'])

# %% [markdown]
# #### Checking the hundled missing values

# %%
#check missing values of test dataset
preprocess.get_missing_data_percentage(test_df)
# Out:
#                            Total    %
# Date                           0  0.0
# CompetitionOpenSinceYear       0  0.0
# weekofyear                     0  0.0
# weekday                        0  0.0
# Day                            0  0.0
# Month                          0  0.0
# Year                           0  0.0
# PromoInterval                  0  0.0
# Promo2SinceYear                0  0.0
# Promo2SinceWeek                0  0.0
# Promo2                         0  0.0
# CompetitionOpenSinceMonth      0  0.0
# Id                             0  0.0
# CompetitionDistance            0  0.0
# Assortment                     0  0.0
# StoreType                      0  0.0
# SchoolHoliday                  0  0.0
# StateHoliday                   0  0.0
# Promo                          0  0.0
# Open                           0  0.0
# DayOfWeek                      0  0.0
# Store                          0  0.0
# weekend                        0  0.0

# %%
#checking for missing value of train dataset
preprocess.get_missing_data_percentage(train_df)
# Out:
#                            Total    %
# Date                           0  0.0
# Store                          0  0.0
# weekofyear                     0  0.0
# weekday                        0  0.0
# Day                            0  0.0
# Month                          0  0.0
# Year                           0  0.0
# PromoInterval                  0  0.0
# Promo2SinceYear                0  0.0
# Promo2SinceWeek                0  0.0
# Promo2                         0  0.0
# CompetitionOpenSinceYear       0  0.0
# CompetitionOpenSinceMonth      0  0.0
# CompetitionDistance            0  0.0
# Assortment                     0  0.0
# StoreType                      0  0.0
# SchoolHoliday                  0  0.0
# StateHoliday                   0  0.0
# Promo                          0  0.0
# Open                           0  0.0
# Customers                      0  0.0
# Sales                          0  0.0
# DayOfWeek                      0  0.0
# weekend                        0  0.0

# %% [markdown]
# #### Handling outliers

# %%
#ploting outliers
sns.set()
plt.boxplot(train_df[['Sales', 'Customers']])
plt.show()

# %%
# Replace Outliers with IQR
df = preprocess.replace_outliers_iqr(train_df, ['Sales', 'Customers'])

# %%
#show handled outlier or after treatment of the outliers
sns.set()
plt.boxplot(train_df[['Sales', 'Customers']])
plt.show()

# %%
train_df.head()
# Out:
#          Date  Store  DayOfWeek   Sales  Customers  Open  Promo StateHoliday  \
# 0  2015-07-31      1          4  5263.0      555.0     1      1            0
# 1  2015-07-30      1          3  5020.0      546.0     1      1            0
# 2  2015-07-29      1          2  4782.0      523.0     1      1            0
# 3  2015-07-28      1          1  5011.0      560.0     1      1            0
# 4  2015-07-27      1          0  6102.0      612.0     1      1            0
#
#    SchoolHoliday StoreType  ... Promo2  Promo2SinceWeek  Promo2SinceYear  \
# 0              1         c  ...      0             22.0           2012.0
# 1              1         c  ...      0             22.0           2012.0
# 2              1         c  ...      0             22.0           2012.0
# 3              1         c  ...      0             22.0           2012.0
# 4              1         c  ...      0             22.0           2012.0
#
# ...

# %%
#Drop Customers column from training data because it is not present in the test data
train_df.drop('Customers',inplace = True, axis=1)

# %% [markdown]
# ### Label Encoding

# %% [markdown]
# Categorical Columns: PromoInterval, Assortment, StoreType

# %%
categorical_columns = ['PromoInterval', 'Assortment', 'StoreType']
# Label encoding
label_encoded_columns = preprocess.label_encode(train_df, categorical_columns)

# %%
train_df.drop(categorical_columns, axis=1, inplace=True)
# Merge DataFrames
train_df = pd.concat([train_df, label_encoded_columns], axis=1)

# %%
# show the details
train_df.dtypes
# Out:
# Date                          object
# Store                          int64
# DayOfWeek                      int64
# Sales                        float64
# Open                           int64
# Promo                          int64
# StateHoliday                  object
# SchoolHoliday                  int64
# CompetitionDistance          float64
# CompetitionOpenSinceMonth    float64
# CompetitionOpenSinceYear     float64
# Promo2                         int64
# Promo2SinceWeek              float64
# Promo2SinceYear              float64
# Year                           int64
# Month                          int64
# Day                            int64
# weekday                        int64
# weekofyear                     int64
# weekend                        int64
# PromoInterval                  int32
# Assortment                     int32
# StoreType                      int32
# dtype: object

# %%
#sort values
train_df.sort_values(["Store"], ignore_index=True, inplace=True)
test_df.sort_values(["Store"], ignore_index=True, inplace=True)
train_df.sort_values(["Year","Month","Day"], ascending=False ,ignore_index=True, inplace=True)
test_df.sort_values(["Year","Month","Day"], ascending=False ,ignore_index=True, inplace=True)

# %%
#Correlation matrix
corr_matrix = train_df.corr()
corr_matrix["Sales"].sort_values(ascending=False)
# Out:
# Sales                        1.000000
# Open                         0.715977
# Promo                        0.468557
# SchoolHoliday                0.088484
# Assortment                   0.074635
# weekofyear                   0.050223
# Month                        0.045805
# Promo2SinceWeek              0.033582
# Year                         0.025718
# CompetitionOpenSinceYear     0.008260
# Store                        0.003404
# Promo2SinceYear             -0.004713
# PromoInterval               -0.004929
# StoreType                   -0.004961
# Day                         -0.011411
# CompetitionDistance         -0.012095
# CompetitionOpenSinceMonth   -0.020931
# Promo2                      -0.084233
# weekend                     -0.279645
# DayOfWeek                   -0.481886
# weekday                     -0.481886
# Name: Sales, dtype: float64

# %% [markdown]
# Save train and test data

# %%
train_df.to_csv('../data/train_processed.csv', index=True)
test_df.to_csv('../data/test_processed.csv', index=True)
